# %%
import pandas as pd

# %%
df_nba = pd.read_csv('NBA_Players.csv')

# %%
df_nba.head()
# Out:
#              TEAM          NAME   EXPERIENCE  \
# 0  Boston Celtics   Aron Baynes            6
# 1  Boston Celtics  Justin Bibbs            0
# 2  Boston Celtics   Jabari Bird            1
# 3  Boston Celtics  Jaylen Brown            2
# 4  Boston Celtics     PJ Dozier            1
#
#                                            URL  POSITION  AGE      HT      WT  \
# 0  http://www.espn.com/nba/player/_/id/2968439        SF   31  208.28  117.65
# 1  http://www.espn.com/nba/player/_/id/3147500         G   22  195.58   99.55
# 2  http://www.espn.com/nba/player/_/id/3064308        SG   24  198.12   89.59
# 3  http://www.espn.com/nba/player/_/id/3917376         F   21  200.66   99.55
# 4  http://www.espn.com/nba/player/_/id/3923250        PG   21  198.12   92.76
#
#             COLLEGE      SALARY  ...    FGP   THM_THA    THP   FTM_FTA    FTP  \
# 0  Washington State   5,193,600  ...  0.502   0.0-0.1  0.143   1.0-1.3  0.802
# ...

# %%
df_nba.columns
#stephen curry
# Out:
# Index(['TEAM', ' NAME', ' EXPERIENCE', ' URL', ' POSITION', ' AGE', ' HT',
#        ' WT', ' COLLEGE', ' SALARY', ' PPG_LAST_SEASON', ' APG_LAST_SEASON',
#        ' RPG_LAST_SEASON', ' PER_LAST_SEASON', ' PPG_CAREER', ' APG_CAREER',
#        ' RGP_CAREER', ' GP', ' MPG', ' FGM_FGA', ' FGP', ' THM_THA', ' THP',
#        ' FTM_FTA', ' FTP', ' APG', ' BLKPG', ' STLPG', ' TOPG', ' PPG'],
#       dtype='object')

# %%
df2 = df_nba.set_index(' NAME')
df2.loc['Aron Baynes']
# Out:
# --------------------------------------------------------------
# KeyError                     Traceback (most recent call last)
# c:\users\diego\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Aron Baynes'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                     Traceback (most recent call last)
# <ipython-input-50-fae71f0f3a3c> in <module>
#       1 df2 = df_nba[' NAME']
# ----> 2 df2.loc['Aron Baynes']
#
# ...
