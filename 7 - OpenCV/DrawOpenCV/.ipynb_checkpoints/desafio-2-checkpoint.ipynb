# %% [markdown]
# ## Desafio 2
#
#
# A partir das 3 imagens existentes na pasta imagens no Github, crie os seguintes componentes em cada imagem e a salve posteriomente modificando o nome para o final “_processed.png”.
#
# Na imagem 1 detalhe com círculos os rostos encontrados e o sexo da cada ator nela.
#
# Na imagem 2 detalhe com retângulos os veículos encontrados e informe o fabricante de cada veículo.
#
# Na imagem 3 detalhe com círculos as placas de trânsito e informe o significado delas.

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# **Imagem 1: rostos**

# %%
image_rostos = cv2.imread("imagens/rostos.jpg")
cv2.imshow("teste",image_rostos)
cv2.waitKey()
cv2.destroyAllWindows()
plt.imshow(image_rostos)
plt.show()

# %%
###### Escreve seu código aqui



######
cv2.imwrite("rostos_processed.png", image_rostos)
image_plt = mpimg.imread("rostos_processed.png")
plt.imshow(image_plt)
plt.show()

# %% [markdown]
# **Imagem 2: veículos**

# %%
image_carros = cv2.imread("imagens/carros.jpg")
cv2.imshow("teste",image_carros)
cv2.waitKey()
cv2.destroyAllWindows()
plt.imshow(image_carros)
plt.show()

# %%
###### Escreve seu código aqui



######
cv2.imwrite("carros_processed.png", image_carros)
image_plt = mpimg.imread("carros_processed.png")
plt.imshow(image_plt)
plt.show()

# %%
image_placas = cv2.imread("imagens/placa-transito.jpg")
image_small = cv2.resize(image_placas, (0,0), fx=0.3, fy=0.3) 
cv2.imwrite("imagens/placa-transito-small.jpg", image_small)

image_placas = image_small.copy()

cv2.imshow("teste",image_placas)
cv2.waitKey()
cv2.destroyAllWindows()
plt.imshow(image_placas)
plt.show()

# %%
###### Escreve seu código aqui



######
cv2.imwrite("placas_processed.png", image_placas)
image_plt = mpimg.imread("placas_processed.png")
plt.imshow(image_plt)
plt.show()
