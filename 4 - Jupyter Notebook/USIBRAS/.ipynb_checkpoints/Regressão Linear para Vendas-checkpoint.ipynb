# %%
import pandas as pd

# %%
df = pd.read_excel("Faturados.xlsx", index_col = 0)

# %%
df.head(3)
# Out:
#        EMISSAO_PEDIDO ENTREGA_PEDIDO  PEDIDO CODIGO_CLIENTE LOJA_CLIENTE  \
# FILIAL
# 1          2018-10-16     2019-04-18  052921         I8I9BA           F3
# 1          2018-10-16     2019-06-14  052922         I8I9BA           F3
# 1          2018-10-16     2019-08-16  052925         I8I9BA           F3
#
#        NOME_CLIENTE ESTADO_CLIENTE CIDADE_CLIENTE    PAIS SEGMENTO  ...  \
# FILIAL                                                              ...
# 1       FRUISEC S.A             EX       EXTERIOR  FRANCA  ATACADO  ...
# 1       FRUISEC S.A             EX       EXTERIOR  FRANCA  ATACADO  ...
# 1       FRUISEC S.A             EX       EXTERIOR  FRANCA  ATACADO  ...
#
#        VL_UNIT_VENDIDO VL_TOTAL_VENDIDO  NOTA_FISCAL SERIE_NOTA EMISSAO_NOTA  \
# FILIAL
# 1           143.470571         100429.4        41665          1   2019-04-12
# 1           143.470571         100429.4        42596          1   2019-07-10
# ...

# %%
df.LINHA.unique()
# Out:
# array(['GRANEL', nan, 'NUTS CLUB', 'EMPORIO', 'SWEET NUTS',
#        'FOOD SERVICE', 'CAJUMIL', 'IRACEMA'], dtype=object)

# %%
df = df[df.ESTADO_CLIENTE != 'EX' and ]

# %%
df.head()
# Out:
#        EMISSAO_PEDIDO ENTREGA_PEDIDO  PEDIDO CODIGO_CLIENTE LOJA_CLIENTE  \
# FILIAL
# 1          2019-01-23     2019-04-10  054030         6I2H47           EL
# 1          2019-02-01     2019-04-05  054111         B3CBJI           1L
# 1          2019-02-07     2019-04-17  054156         6I2H47           E2
# 1          2019-02-08     2019-04-03  054180          B56AA           1L
# 1          2019-02-08     2019-05-02  054181          B56AA           1L
#
#                                              NOME_CLIENTE ESTADO_CLIENTE  \
# FILIAL
# 1                                    BIMBO DO BRASIL LTDA             RJ
# 1       WICKBOLD E NOSSO PAO INDUSTRIAS ALIMENTICIAS LTDA             SP
# 1                                    BIMBO DO BRASIL LTDA             SP
# 1       KIM NETO INDUSTRIA E COMERCIO DE PANIFICACAO LTDA             SP
# 1       KIM NETO INDUSTRIA E COMERCIO DE PANIFICACAO LTDA             SP
#
# ...
